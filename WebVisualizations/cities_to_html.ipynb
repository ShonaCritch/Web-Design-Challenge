# %%
# Dependencies and Setup
import pandas as pd

#file path to saved csv dataframe
file = 'resources/cities_data.csv'

# %%
cities_df = pd.read_csv(file, encoding="ISO-8859-1")
print(len(cities_df))
# Out:
# 513

# %%
#save as html table
cities = cities_df.to_html()
print(cities)
#html = dataFrame.to_html();
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>City</th>
#       <th>Cloudiness</th>
#       <th>Country</th>
#       <th>Date</th>
#       <th>Humidity</th>
#       <th>Lat</th>
#       <th>Lng</th>
#       <th>Max Temp</th>
#       <th>Wind Speed</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Staritsa</td>
#       <td>98</td>
#       <td>RU</td>
#       <td>1601608300</td>
#       <td>73</td>
#       <td>56.51</td>
#       <td>34.94</td>
#       <td>8.63</td>
#       <td>2.95</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Bluff</td>
#       <td>100</td>
#       <td>NZ</td>
#       <td>1601608184</td>
#       <td>59</td>
#       <td>-46.60</td>
#       <td>168.33</td>
#       <td>14.44</td>
#       <td>4.02</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>KlaksvÃ­k</td>
#       <td>100</td>
#       <td>FO</td>
#       <td>1601608192</td>
# ...

# %%
#save cities html as text file
cities_df.to_html('resources/cities.html')
